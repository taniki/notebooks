# %% [markdown]
# # Récupération des listes de titres et de leur(s) propriétaires à partir de wikidata
#
# [Requête exécutée directement sur le site](https://query.wikidata.org/embed.html#SELECT%20%3Fitem%20%3FitemLabel%20%3Fowner%20%3FownerLabel%20WHERE%20%7B%0A%20%20%7B%0A%20%20%20%20%23%20Newspaper%0A%20%20%20%20%3Fitem%20wdt%3AP31%2Fwdt%3AP279*%20wd%3AQ11032.%0A%20%20%7D%0A%20%20UNION%0A%20%20%7B%0A%20%20%20%20%23%20Magazine%0A%20%20%20%20%3Fitem%20wdt%3AP31%2Fwdt%3AP279*%20wd%3AQ41298.%0A%20%20%7D%0A%20%20UNION%0A%20%20%7B%0A%20%20%20%20%23%20P%C3%A9riodique%0A%20%20%20%20%3Fitem%20wdt%3AP31%2Fwdt%3AP279*%20wd%3AQ1002697.%0A%20%20%7D%0A%20%0A%20%20%23%20France%0A%20%20%3Fitem%20wdt%3AP17%20wd%3AQ142.%0A%20%20%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%3Fitem%20wdt%3AP127%20%3Fowner.%0A%20%20%7D%0A%20%20%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22%5BAUTO_LANGUAGE%5D%2Cen%22.%20%7D%0A%7D)

# %%
import rdflib
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
query = """
SELECT ?item ?itemLabel ?owner ?ownerLabel WHERE {
  {
    # Newspaper
    # ?item wdt:P31/wdt:P279* wd:Q11032.
  }
  UNION
  {
    # Magazine
    # ?item wdt:P31/wdt:P279* wd:Q41298.
  }
  UNION
  {
    # Périodique
    # ?item wdt:P31/wdt:P279* wd:Q1002697.
  }
 
  # France
  # ?item wdt:P17 wd:Q142.
  
  OPTIONAL {
    # ?item wdt:P127 ?owner.
  }
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

sparql.setQuery(query)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'vars': ['item', 'itemLabel', 'owner', 'ownerLabel']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q377629'},
#     'itemLabel': {'type': 'literal', 'value': 'Télérama', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117473'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Le Monde',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q501461'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Journal du Dimanche',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3216152'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Lagardère Active',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q511952'},
#     'itemLabel': {'type': 'literal', 'value': 'Politis', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q517477'},
#     'itemLabel': {'type': 'literal', 'value': 'Télé Poche', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1097962'},
#     'itemLabel': {'type': 'literal', 'value': 'Q1097962'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q858121'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Monde diplomatique',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55180422'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Le Monde Diplomatique SA',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q923193'},
#     'itemLabel': {'type': 'literal', 'value': 'Les Échos', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q504998'},
#     'ownerLabel': {'type': 'literal', 'value': 'LVMH', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q964945'},
#     'itemLabel': {'type': 'literal', 'value': 'Rue89', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117520'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117520'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1043104'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Charlie Hebdo',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3433199'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Laurent Sourisseau',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1044328'},
#     'itemLabel': {'type': 'literal', 'value': "L'Obs", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q13709'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Canard enchaîné',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q32855'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Pas-de-Calais Independent',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q729749'},
#     'itemLabel': {'type': 'literal', 'value': 'Q729749'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117466'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe La Voix',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q742587'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Dépêche du Midi',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q751228'},
#     'itemLabel': {'type': 'literal', 'value': 'Haratch', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q770596'},
#     'itemLabel': {'type': 'literal', 'value': "L'Express", 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q15714038'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Patrick Drahi',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q815748'},
#     'itemLabel': {'type': 'literal', 'value': "L'Équipe", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1252739'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Jeune Afrique',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1674967'},
#     'itemLabel': {'type': 'literal', 'value': 'Q1674967'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1799197'},
#     'itemLabel': {'type': 'literal', 'value': 'La Tribune', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2758142'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Les Inrockuptibles',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3299928'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Matthieu Pigasse',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2823781'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2823781'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2825340'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2825340'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2864718'},
#     'itemLabel': {'type': 'literal', 'value': 'Art press', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2931935'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2931935'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2947983'},
#     'itemLabel': {'type': 'literal', 'value': 'Challenges', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117520'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117520'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3010740'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3010740'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3410475'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3410475'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3083378'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Bougie du Sapeur',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3134347'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3134347'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3186871'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3186871'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3201581'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3201581'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2866000'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Artémis',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202306'},
#     'itemLabel': {'type': 'literal', 'value': "L'Argus", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3204140'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3204140'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117466'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe La Voix',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3205144'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3205144'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3205828'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Œil électrique",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3209216'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3209216'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3211144'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Nouvelle République du Centre-Ouest',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3211914'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3211914'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3212643'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3212643'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3408901'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Prefecture of Police',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3213306'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Tribune Républicaine',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3224515'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Le Messager',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3213561'},
#     'itemLabel': {'type': 'literal', 'value': 'La Vie', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117473'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Le Monde',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3221870'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3221870'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3221895'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3221895'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3221956'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Cri du peuple',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3223073'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Gastronome',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3223501'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Huffington Post France',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3224319'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3224319'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3224676'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Monde de l'éducation",
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117473'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Le Monde',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3224708'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3224708'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226097'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Pèlerin', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226113'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3226113'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226277'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3226277'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226743'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3226743'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3227888'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3227888'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3410475'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3410475'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3237841'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3237841'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3272374'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Monde mensuel',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3291276'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Marianne (journal 1932-1940)',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3391060'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Plaisir de France',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3454763'},
#     'itemLabel': {'type': 'literal', 'value': 'Réforme', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3500156'},
#     'itemLabel': {'type': 'literal', 'value': 'Stratégies', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3512617'},
#     'itemLabel': {'type': 'literal',
#      'value': 'TV Magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3516830'},
#     'itemLabel': {'type': 'literal', 'value': 'Technikart', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3538935'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3538935'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3546531'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Télé 7 Jours',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3216152'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Lagardère Active',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3553781'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Valeurs Actuelles',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3488751'},
#     'ownerLabel': {'type': 'literal', 'value': 'Socpresse', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3553781'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Valeurs Actuelles',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7912502'},
#     'ownerLabel': {'type': 'literal', 'value': 'Valmonde', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3563155'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3563155'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3570471'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3570471'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3592710'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3592710'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6463467'},
#     'itemLabel': {'type': 'literal', 'value': 'La Loi', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6465035'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La République sociale indépendante',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6465875'},
#     'itemLabel': {'type': 'literal',
#      'value': "La Voix de l'Est",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6506830'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Cuir', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6507797'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Travailleur du Centre Ouest',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7418950'},
#     'itemLabel': {'type': 'literal', 'value': 'Sans fil', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16536228'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16536228'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16682137'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16682137'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16303413'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16303413'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q24506902'},
#     'itemLabel': {'type': 'literal', 'value': 'Q24506902'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q24938467'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Abeille du Bugey et du pays de Gex',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q15241166'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Russie opprimée',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26046063'},
#     'itemLabel': {'type': 'literal', 'value': 'Q26046063'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26821157'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Écho du Pas-de-Calais",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55139678'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Démocratie pacifique',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55527330'},
#     'itemLabel': {'type': 'literal', 'value': "L'Hermine", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q20830821'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Paysan Breton',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21514747'},
#     'itemLabel': {'type': 'literal', 'value': 'Q21514747'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28493296'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28493296'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28858842'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28858842'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q22681427'},
#     'itemLabel': {'type': 'literal', 'value': 'Q22681427'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q38941275'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Mon Lapin Quotidien',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q40163460'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Garde National',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q40163826'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Journal des Demoiselles',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41939671'},
#     'itemLabel': {'type': 'literal', 'value': 'Q41939671'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42428798'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Antijuif algérien",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43534671'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Courrier de l'Atlas",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47086387'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Petit Caporal',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47472742'},
#     'itemLabel': {'type': 'literal', 'value': 'Zangou', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10977'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Progrès', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q12461'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Monde', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117473'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Le Monde',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q13717'},
#     'itemLabel': {'type': 'literal', 'value': 'Libération', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16534243'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bruno Ledoux',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q13717'},
#     'itemLabel': {'type': 'literal', 'value': 'Libération', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21007923'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'SFR Presse',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142348'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Parisien', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q504998'},
#     'ownerLabel': {'type': 'literal', 'value': 'LVMH', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q203853'},
#     'itemLabel': {'type': 'literal', 'value': 'Nice-Matin', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q17355286'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q17355286'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q216047'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Figaro', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1434948'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Dassault Group',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57330816'},
#     'itemLabel': {'type': 'literal', 'value': 'Q57330816'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q381431'},
#     'itemLabel': {'type': 'literal',
#      'value': "Les Dernières Nouvelles d'Alsace",
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2883390'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q2883390'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1135428'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Corse-Matin',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1137404'},
#     'itemLabel': {'type': 'literal', 'value': "L'Humanité", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7245532'},
#     'itemLabel': {'type': 'literal', 'value': '20 minutes', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117548'},
#     'ownerLabel': {'type': 'literal', 'value': 'Rossel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q51879657'},
#     'itemLabel': {'type': 'literal',
#      'value': 'France Info',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55998492'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Pro Armenia',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56037554'},
#     'itemLabel': {'type': 'literal', 'value': 'Fier Panda', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1230298'},
#     'itemLabel': {'type': 'literal', 'value': 'La Croix', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q929887'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bayard Presse',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1465340'},
#     'itemLabel': {'type': 'literal', 'value': 'Midi Libre', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3233440'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3233440'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1799045'},
#     'itemLabel': {'type': 'literal', 'value': 'La Provence', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q728645'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bernard Tapie',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3065584'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Famille chrétienne',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2630418'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Média-Participations',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3269634'},
#     'itemLabel': {'type': 'literal', 'value': 'Lyon Poche', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3562488'},
#     'itemLabel': {'type': 'literal',
#      'value': "Voix de l'Ain",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q815748'},
#     'itemLabel': {'type': 'literal', 'value': "L'Équipe", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2375812'},
#     'itemLabel': {'type': 'literal', 'value': 'Nord Éclair', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117466'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe La Voix',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2567583'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Voix du Nord',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117548'},
#     'ownerLabel': {'type': 'literal', 'value': 'Rossel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2642655'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Dauphiné Libéré',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3052319'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Est Républicain",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3088647'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Télégramme',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202605'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3202605'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3210777'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Montagne',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3212572'},
#     'itemLabel': {'type': 'literal', 'value': 'La Réforme', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3212596'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3212596'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3221956'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Cri du peuple',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3225515'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Petit Quotidien',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226748'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Républicain Lorrain',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q12948710'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Ecò dóu bousquetoun",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q14940658'},
#     'itemLabel': {'type': 'literal', 'value': "L'Opinion", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18750711'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Petit Bleu d'Agen",
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117468'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117468'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21197930'},
#     'itemLabel': {'type': 'literal', 'value': 'Q21197930'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57461791'},
#     'itemLabel': {'type': 'literal', 'value': 'Q57461791'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57466475'},
#     'itemLabel': {'type': 'literal', 'value': 'Q57466475'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q51237919'},
#     'itemLabel': {'type': 'literal', 'value': "L'Autorité", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q51926334'},
#     'itemLabel': {'type': 'literal', 'value': "L'Éclair", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q52263479'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Estafette",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q53816063'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Comédie politique',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11014'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Lyon Capitale',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q619342'},
#     'itemLabel': {'type': 'literal', 'value': 'Mediapart', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q762287'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Psychologies',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117548'},
#     'ownerLabel': {'type': 'literal', 'value': 'Rossel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2869404'},
#     'itemLabel': {'type': 'literal', 'value': 'Atlantico', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3141778'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Courrier d'Europe centrale",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3365300'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3365300'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28790859'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28790859'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42415327'},
#     'itemLabel': {'type': 'literal', 'value': 'Q42415327'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q46823240'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Metropolitaine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47330713'},
#     'itemLabel': {'type': 'literal', 'value': 'Paris', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56410936'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Petit Bleu de Lot-et-Garonne',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117468'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117468'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56411831'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Petit bleu de l'Agenais",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q308705'},
#     'itemLabel': {'type': 'literal',
#      'value': 'France Football',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q909176'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Cahiers du cinéma',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q950814'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Palamède',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1125473'},
#     'itemLabel': {'type': 'literal', 'value': 'Positif', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2060322'},
#     'itemLabel': {'type': 'literal', 'value': 'Têtu', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q770037'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Pierre Bergé',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2094663'},
#     'itemLabel': {'type': 'literal', 'value': 'Pif gadget', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2817930'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2817930'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2823597'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2823597'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2844508'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2844508'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2860164'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2860164'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2864574'},
#     'itemLabel': {'type': 'literal', 'value': 'Art actuel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2867323'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Revue francaise des corps gras',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2872499'},
#     'itemLabel': {'type': 'literal', 'value': 'Auto Plus', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2410691'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Mondadori France',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2872499'},
#     'itemLabel': {'type': 'literal', 'value': 'Auto Plus', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2874758'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q2874758'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2890690'},
#     'itemLabel': {'type': 'literal', 'value': "L'Histoire", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2893375'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Beaux Arts magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1684476'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Jazz Magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3129163'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Hebdogiciel',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3151427'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3151427'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3191493'},
#     'itemLabel': {'type': 'literal',
#      'value': 'KR home-studio',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202468'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Assiette au Beurre",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202607'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Auto-Journal",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202617'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Automobile Magazine",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3205039'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3205039'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3205246'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Écran français",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3222785'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Film français',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21694675'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q21694675'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3225267'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Particulier',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3241710'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3241710'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1464960'},
#     'itemLabel': {'type': 'literal', 'value': 'Jazz Hot', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2924387'},
#     'itemLabel': {'type': 'literal', 'value': 'Bremañ', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2933141'},
#     'itemLabel': {'type': 'literal', 'value': 'Q2933141'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3027999'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3027999'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3049620'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Objectif Rhône-Alpes (2007)',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3050567'},
#     'itemLabel': {'type': 'literal', 'value': "Lyon mag'", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3050612'},
#     'itemLabel': {'type': 'literal', 'value': 'Mag2 Lyon', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3054204'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Innov à Lyon',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3076697'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Football magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3093266'},
#     'itemLabel': {'type': 'literal',
#      'value': 'GNU/Linux Magazine France',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3094449'},
#     'itemLabel': {'type': 'literal', 'value': 'Gala', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q481536'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Gruner + Jahr',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3108990'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3108990'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3821109'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Revue indépendante',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3257267'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3257267'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3272224'},
#     'itemLabel': {'type': 'literal',
#      'value': 'L’Humanité Dimanche',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3276862'},
#     'itemLabel': {'type': 'literal', 'value': 'Magic', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3285158'},
#     'itemLabel': {'type': 'literal', 'value': 'Management', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3403917'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Prisma Media',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3295086'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3295086'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3348123'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Objectif soins',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3409088'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Présence Africaine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3410409'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3410409'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1490400'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Lagardère Group',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3414286'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Question de parents',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3475754'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Science & Vie',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3479009'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Septentrion',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3493814'},
#     'itemLabel': {'type': 'literal', 'value': 'Sport auto', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3515605'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Nouvel objectif Rhône-Alpes',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3518519'},
#     'itemLabel': {'type': 'literal', 'value': 'Terra Eco', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3537592'},
#     'itemLabel': {'type': 'literal', 'value': 'Transfuge', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3539962'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Trois couleurs magazine',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q19814222'},
#     'ownerLabel': {'type': 'literal', 'value': 'MK2', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3546543'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Télé Loisirs',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3403917'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Prisma Media',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3562152'},
#     'itemLabel': {'type': 'literal', 'value': 'Voici', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3403917'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Prisma Media',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3568018'},
#     'itemLabel': {'type': 'literal', 'value': 'Wik', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7886312'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Version.net',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6099507'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Guide des lycées et collèges de la région lyonnaise',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q12899083'},
#     'itemLabel': {'type': 'literal',
#      'value': "Bulletin de l'École française d'Extrême-Orient",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11933758'},
#     'itemLabel': {'type': 'literal', 'value': 'Q11933758'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11945008'},
#     'itemLabel': {'type': 'literal', 'value': 'Reclams', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11951617'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Terra Nostra',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16039734'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Bonheurs magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16665590'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Musique bretonne',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5301187'},
#     'ownerLabel': {'type': 'literal', 'value': 'Dastum', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16668777'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16668777'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16672681'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16672681'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18130922'},
#     'itemLabel': {'type': 'literal',
#      'value': 'PlayStation Magazine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q19970443'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Objectif Gard',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q13411445'},
#     'itemLabel': {'type': 'literal', 'value': 'Òc', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q14638330'},
#     'itemLabel': {'type': 'literal', 'value': 'Q14638330'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q20088589'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Hypertextes et hypermédias',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q23002020'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Annonces Automobile',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q17176729'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Lyon quartiers',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q17190321'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Ambiances lyonnaises',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18611915'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Keyboards recording',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18611932'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Recording musicien',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18611937'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Keyboards home studio',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
# ...
#     'itemLabel': {'type': 'literal', 'value': 'Q3541634'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3592584'},
#     'itemLabel': {'type': 'literal', 'value': 'Études', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6463467'},
#     'itemLabel': {'type': 'literal', 'value': 'La Loi', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18745517'},
#     'itemLabel': {'type': 'literal', 'value': 'Q18745517'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18750714'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Nord Littoral',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117466'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe La Voix',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18762364'},
#     'itemLabel': {'type': 'literal', 'value': 'Q18762364'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18762368'},
#     'itemLabel': {'type': 'literal', 'value': 'Q18762368'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18762370'},
#     'itemLabel': {'type': 'literal', 'value': 'Q18762370'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q19945265'},
#     'itemLabel': {'type': 'literal', 'value': 'Q19945265'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q20726084'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Canard de Nantes à Brest',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q20828252'},
#     'itemLabel': {'type': 'literal',
#      'value': "La Lettre de l'AFMA (Paris)",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21009193'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le XIXe siècle',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16467668'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16467668'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16534812'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16534812'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q24931013'},
#     'itemLabel': {'type': 'literal', 'value': 'Q24931013'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q24932530'},
#     'itemLabel': {'type': 'literal', 'value': 'Q24932530'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47068129'},
#     'itemLabel': {'type': 'literal', 'value': 'Zaporojetz', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3052319'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Est Républicain",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3088647'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Télégramme',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3202605'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3202605'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26709624'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Les Affiches de Paris (Paris. 1745)',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26709762'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Journal des théâtres, de littérature et des arts',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26962157'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Badminton Magazine - Revue de la Fédération Française de Badminton',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q26962484'},
#     'itemLabel': {'type': 'literal',
#      'value': 'France Badminton',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16628316'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16628316'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16653731'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16653731'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3410475'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3410475'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16654015'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16654015'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16670221'},
#     'itemLabel': {'type': 'literal', 'value': 'Q16670221'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q25395689'},
#     'itemLabel': {'type': 'literal', 'value': 'Réseaux', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3210777'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Montagne',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3212572'},
#     'itemLabel': {'type': 'literal', 'value': 'La Réforme', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3212596'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3212596'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3221956'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Cri du peuple',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3225515'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Petit Quotidien',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3226748'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Républicain Lorrain',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3365300'},
#     'itemLabel': {'type': 'literal', 'value': 'Q3365300'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28495383'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28495383'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28495774'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28495774'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10977'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Progrès', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q12461'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Monde', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117473'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe Le Monde',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q13717'},
#     'itemLabel': {'type': 'literal', 'value': 'Libération', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16534243'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bruno Ledoux',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q13717'},
#     'itemLabel': {'type': 'literal', 'value': 'Libération', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21007923'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'SFR Presse',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142348'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Parisien', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q504998'},
#     'ownerLabel': {'type': 'literal', 'value': 'LVMH', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q203853'},
#     'itemLabel': {'type': 'literal', 'value': 'Nice-Matin', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q17355286'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q17355286'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q216047'},
#     'itemLabel': {'type': 'literal', 'value': 'Le Figaro', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1434948'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Dassault Group',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q381431'},
#     'itemLabel': {'type': 'literal',
#      'value': "Les Dernières Nouvelles d'Alsace",
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2883390'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q2883390'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q14940658'},
#     'itemLabel': {'type': 'literal', 'value': "L'Opinion", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3269634'},
#     'itemLabel': {'type': 'literal', 'value': 'Lyon Poche', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q12948710'},
#     'itemLabel': {'type': 'literal',
#      'value': "L'Ecò dóu bousquetoun",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q24938467'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Abeille du Bugey et du pays de Gex',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42415327'},
#     'itemLabel': {'type': 'literal', 'value': 'Q42415327'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q46823240'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Metropolitaine',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q51879657'},
#     'itemLabel': {'type': 'literal',
#      'value': 'France Info',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56037554'},
#     'itemLabel': {'type': 'literal', 'value': 'Fier Panda', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57461791'},
#     'itemLabel': {'type': 'literal', 'value': 'Q57461791'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57466475'},
#     'itemLabel': {'type': 'literal', 'value': 'Q57466475'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1135428'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Corse-Matin',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1137404'},
#     'itemLabel': {'type': 'literal', 'value': "L'Humanité", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1230298'},
#     'itemLabel': {'type': 'literal', 'value': 'La Croix', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q929887'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bayard Presse',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1465340'},
#     'itemLabel': {'type': 'literal', 'value': 'Midi Libre', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3233440'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3233440'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q7245532'},
#     'itemLabel': {'type': 'literal', 'value': '20 minutes', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117548'},
#     'ownerLabel': {'type': 'literal', 'value': 'Rossel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q18750711'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Petit Bleu d'Agen",
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117468'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117468'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q28790859'},
#     'itemLabel': {'type': 'literal', 'value': 'Q28790859'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47330713'},
#     'itemLabel': {'type': 'literal', 'value': 'Paris', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q815748'},
#     'itemLabel': {'type': 'literal', 'value': "L'Équipe", 'xml:lang': 'en'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q619342'},
#     'itemLabel': {'type': 'literal', 'value': 'Mediapart', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1799045'},
#     'itemLabel': {'type': 'literal', 'value': 'La Provence', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q728645'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Bernard Tapie',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2375812'},
#     'itemLabel': {'type': 'literal', 'value': 'Nord Éclair', 'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117466'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Groupe La Voix',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2567583'},
#     'itemLabel': {'type': 'literal',
#      'value': 'La Voix du Nord',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117548'},
#     'ownerLabel': {'type': 'literal', 'value': 'Rossel', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2642655'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Dauphiné Libéré',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2869404'},
#     'itemLabel': {'type': 'literal', 'value': 'Atlantico', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3065584'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Famille chrétienne',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2630418'},
#     'ownerLabel': {'type': 'literal',
#      'value': 'Média-Participations',
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3141778'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Courrier d'Europe centrale",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3269634'},
#     'itemLabel': {'type': 'literal', 'value': 'Lyon Poche', 'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3562488'},
#     'itemLabel': {'type': 'literal',
#      'value': "Voix de l'Ain",
#      'xml:lang': 'en'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21197930'},
#     'itemLabel': {'type': 'literal', 'value': 'Q21197930'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56410936'},
#     'itemLabel': {'type': 'literal',
#      'value': 'Le Petit Bleu de Lot-et-Garonne',
#      'xml:lang': 'en'},
#     'owner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3117468'},
#     'ownerLabel': {'type': 'literal', 'value': 'Q3117468'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q56411831'},
#     'itemLabel': {'type': 'literal',
#      'value': "Le Petit bleu de l'Agenais",
#      'xml:lang': 'en'}}]}}

# %%
titres = []

for item in results['results']['bindings']:
    titres.append( [ item['itemLabel']['value'] ])

titres
# Out:
# [['Télérama'],
#  ['Le Journal du Dimanche'],
#  ['Politis'],
#  ['Télé Poche'],
#  ['Q1097962'],
#  ['Le Monde diplomatique'],
#  ['Les Échos'],
#  ['Rue89'],
#  ['Charlie Hebdo'],
#  ["L'Obs"],
#  ['Le Canard enchaîné'],
#  ['Pas-de-Calais Independent'],
#  ['Q729749'],
#  ['La Dépêche du Midi'],
#  ['Haratch'],
#  ["L'Express"],
#  ["L'Équipe"],
#  ['Jeune Afrique'],
#  ['Q1674967'],
#  ['La Tribune'],
#  ['Les Inrockuptibles'],
#  ['Q2823781'],
#  ['Q2825340'],
#  ['Art press'],
#  ['Q2931935'],
#  ['Challenges'],
#  ['Q3010740'],
#  ['La Bougie du Sapeur'],
#  ['Q3134347'],
#  ['Q3186871'],
#  ['Q3201581'],
#  ["L'Argus"],
#  ['Q3204140'],
#  ['Q3205144'],
#  ["L'Œil électrique"],
#  ['Q3209216'],
#  ['La Nouvelle République du Centre-Ouest'],
#  ['Q3211914'],
#  ['Q3212643'],
#  ['La Tribune Républicaine'],
#  ['La Vie'],
#  ['Q3221870'],
#  ['Q3221895'],
#  ['Le Cri du peuple'],
#  ['Le Gastronome'],
#  ['Huffington Post France'],
#  ['Q3224319'],
#  ["Le Monde de l'éducation"],
#  ['Q3224708'],
#  ['Le Pèlerin'],
#  ['Q3226113'],
#  ['Q3226277'],
#  ['Q3226743'],
#  ['Q3227888'],
#  ['Q3237841'],
#  ['Le Monde mensuel'],
#  ['Marianne (journal 1932-1940)'],
#  ['Plaisir de France'],
#  ['Réforme'],
#  ['Stratégies'],
#  ['TV Magazine'],
#  ['Technikart'],
#  ['Q3538935'],
#  ['Télé 7 Jours'],
#  ['Valeurs Actuelles'],
#  ['Valeurs Actuelles'],
#  ['Q3563155'],
#  ['Q3570471'],
#  ['Q3592710'],
#  ['La Loi'],
#  ['La République sociale indépendante'],
#  ["La Voix de l'Est"],
#  ['Le Cuir'],
#  ['Le Travailleur du Centre Ouest'],
#  ['Sans fil'],
#  ['Q16536228'],
#  ['Q16682137'],
#  ['Q16303413'],
#  ['Q24506902'],
#  ['Abeille du Bugey et du pays de Gex'],
#  ['La Russie opprimée'],
#  ['Q26046063'],
#  ["L'Écho du Pas-de-Calais"],
#  ['La Démocratie pacifique'],
#  ["L'Hermine"],
#  ['Paysan Breton'],
#  ['Q21514747'],
#  ['Q28493296'],
#  ['Q28858842'],
#  ['Q22681427'],
#  ['Mon Lapin Quotidien'],
#  ['Le Garde National'],
#  ['Journal des Demoiselles'],
#  ['Q41939671'],
#  ["L'Antijuif algérien"],
#  ["Le Courrier de l'Atlas"],
#  ['Le Petit Caporal'],
#  ['Zangou'],
#  ['Le Progrès'],
#  ['Le Monde'],
#  ['Libération'],
#  ['Libération'],
#  ['Le Parisien'],
#  ['Nice-Matin'],
#  ['Le Figaro'],
#  ['Q57330816'],
#  ["Les Dernières Nouvelles d'Alsace"],
#  ['Corse-Matin'],
#  ["L'Humanité"],
#  ['20 minutes'],
#  ['France Info'],
#  ['Pro Armenia'],
#  ['Fier Panda'],
#  ['La Croix'],
#  ['Midi Libre'],
#  ['La Provence'],
#  ['Famille chrétienne'],
#  ['Lyon Poche'],
#  ["Voix de l'Ain"],
#  ["L'Équipe"],
#  ['Nord Éclair'],
#  ['La Voix du Nord'],
#  ['Le Dauphiné Libéré'],
#  ["L'Est Républicain"],
#  ['Le Télégramme'],
#  ['Q3202605'],
#  ['La Montagne'],
#  ['La Réforme'],
#  ['Q3212596'],
#  ['Le Cri du peuple'],
#  ['Le Petit Quotidien'],
#  ['Le Républicain Lorrain'],
#  ["L'Ecò dóu bousquetoun"],
#  ["L'Opinion"],
#  ["Le Petit Bleu d'Agen"],
#  ['Q21197930'],
#  ['Q57461791'],
#  ['Q57466475'],
#  ["L'Autorité"],
#  ["L'Éclair"],
#  ["L'Estafette"],
#  ['La Comédie politique'],
#  ['Lyon Capitale'],
#  ['Mediapart'],
#  ['Psychologies'],
#  ['Atlantico'],
#  ["Le Courrier d'Europe centrale"],
#  ['Q3365300'],
#  ['Q28790859'],
#  ['Q42415327'],
#  ['Metropolitaine'],
#  ['Paris'],
#  ['Le Petit Bleu de Lot-et-Garonne'],
#  ["Le Petit bleu de l'Agenais"],
#  ['France Football'],
#  ['Cahiers du cinéma'],
#  ['Le Palamède'],
#  ['Positif'],
#  ['Têtu'],
#  ['Pif gadget'],
#  ['Q2817930'],
#  ['Q2823597'],
#  ['Q2844508'],
#  ['Q2860164'],
#  ['Art actuel'],
#  ['Revue francaise des corps gras'],
#  ['Auto Plus'],
#  ['Auto Plus'],
#  ["L'Histoire"],
#  ['Beaux Arts magazine'],
#  ['Jazz Magazine'],
#  ['Hebdogiciel'],
#  ['Q3151427'],
#  ['KR home-studio'],
#  ["L'Assiette au Beurre"],
#  ["L'Auto-Journal"],
#  ["L'Automobile Magazine"],
#  ['Q3205039'],
#  ["L'Écran français"],
#  ['Le Film français'],
#  ['Le Particulier'],
#  ['Q3241710'],
#  ['Jazz Hot'],
#  ['Bremañ'],
#  ['Q2933141'],
#  ['Q3027999'],
#  ['Objectif Rhône-Alpes (2007)'],
#  ["Lyon mag'"],
#  ['Mag2 Lyon'],
#  ['Innov à Lyon'],
#  ['Football magazine'],
#  ['GNU/Linux Magazine France'],
#  ['Gala'],
#  ['Q3108990'],
#  ['La Revue indépendante'],
#  ['Q3257267'],
#  ['L’Humanité Dimanche'],
#  ['Magic'],
#  ['Management'],
#  ['Q3295086'],
#  ['Objectif soins'],
#  ['Présence Africaine'],
#  ['Q3410409'],
#  ['Question de parents'],
#  ['Science & Vie'],
#  ['Septentrion'],
#  ['Sport auto'],
#  ['Le Nouvel objectif Rhône-Alpes'],
#  ['Terra Eco'],
#  ['Transfuge'],
#  ['Trois couleurs magazine'],
#  ['Télé Loisirs'],
#  ['Voici'],
#  ['Wik'],
#  ['Version.net'],
#  ['Guide des lycées et collèges de la région lyonnaise'],
#  ["Bulletin de l'École française d'Extrême-Orient"],
#  ['Q11933758'],
#  ['Reclams'],
#  ['Terra Nostra'],
#  ['Bonheurs magazine'],
#  ['Musique bretonne'],
#  ['Q16668777'],
#  ['Q16672681'],
#  ['PlayStation Magazine'],
#  ['Objectif Gard'],
#  ['Òc'],
#  ['Q14638330'],
#  ['Hypertextes et hypermédias'],
#  ['Annonces Automobile'],
#  ['Lyon quartiers'],
#  ['Ambiances lyonnaises'],
#  ['Keyboards recording'],
#  ['Recording musicien'],
#  ['Keyboards home studio'],
#  ['Sport free attitude'],
#  ['Q17621163'],
#  ['Clés pour le train miniature'],
#  ['Objectifs Rhône-Alpes'],
#  ['Place publique'],
#  ['Lyon découverte'],
#  ['Femina'],
#  ['The Good Life'],
#  ['Journal de Mathematiques Pures et Appliquees'],
#  ['Acquisition and foreign language interaction'],
#  ['Le Fablier'],
#  ['Lignes'],
#  ['Poétique'],
#  ['Q3535682'],
#  ['Tout Prévoir'],
#  ['Q3570471'],
#  ['Q3578981'],
#  ['Q3579382'],
#  ['Q16667342'],
#  ['Q17356495'],
#  ['Q17356504'],
#  ['Q18823085'],
#  ['Q18836656'],
#  ['Q18836803'],
#  ['Q18837179'],
#  ['Q21013033'],
#  ['Carmel'],
#  ['Q22047656'],
#  ['Q22054784'],
#  ['Q22248699'],
#  ['Les périphériques vous parlent'],
#  ['Q22927240'],
#  ['Savoirs'],
#  ['Q24025038'],
#  ['Q24150816'],
#  ['Bulletin officiel des Établissements français de l’Inde'],
#  ['Giff-Wiff'],
#  ['Q25389731'],
#  ['Q25932039'],
#  ["Bulletin de la Société d'études scientifiques et archéologiques de la ville de Draguignan"],
#  ['Q27962734'],
#  ['Q28495549'],
#  ['Le Télémaque'],
#  ['Revue du clergé français'],
#  ['Q38500285'],
#  ['Q40279698'],
#  ['Vers la tradition'],
#  ['Enfance (revue)'],
#  ['Q43459214'],
#  ['Q55286723'],
#  ['Positif'],
#  ['La Hulotte'],
#  ['Agrimuse'],
#  ['Alternatives économiques'],
#  ['Art absolument'],
#  ['Q2933151'],
#  ['Q2939748'],
#  ['Q3002973'],
#  ['Q3047070'],
#  ['Genre & Histoire'],
#  ['Q3149145'],
#  ['Critikat'],
#  ['Néo planète'],
#  ['Objectif soins & management'],
#  ['Wind Magazine'],
#  ['Windsurfing'],
#  ['Q21639502'],
#  ['Le Théâtre illustré'],
#  ["Les Cahiers de l'Entre-Deux-Mers (1994-2011)"],
#  ["Les Cahiers de l'Entre-Deux Mers"],
#  ['Annals of Economics and Statistics'],
#  ["Actes de la Société d'Histoire Naturelle de Paris"],
#  ["Le Panthéon de l'industrie"],
#  ['Q46237041'],
#  ['Q46620531'],
#  ['Koï'],
#  ['Conflits'],
#  ['France Football'],
#  ['SO FOOT'],
#  ['Revue française des sciences de l’information et de la communication'],
#  ['Menorah'],
#  ['Nouvelle Revue Française'],
#  ['La Quinzaine littéraire'],
#  ['Amis-Coop'],
#  ['La Revue Dessinée'],
#  ['Q21009281'],
#  ['Q21514710'],
#  ['Charlie Hebdo'],
#  ['Pif gadget'],
#  ['Q2907477'],
#  ['Politiques et management public'],
#  ['Persée'],
#  ['Jazz Hot'],
#  ['Lire'],
#  ['Grodada'],
#  ['Q3205337'],
#  ['Record'],
#  ['Cliopsy'],
#  ['Q3480448'],
#  ['Q26263213'],
#  ['Revue française des sciences de l’information et de la communication'],
#  ['Photographie.com'],
#  ['Revue Jules Verne'],
#  ['Terra Eco'],
#  ['Le Gorafi'],
#  ['Le Gorafi'],
#  ['Orient XXI'],
#  ['Néoplanète'],
#  ['Q16672681'],
#  ["Levant: cahiers de l'espace méditerranéen"],
#  ["Levant: cahiers de l'espace méditerranéen"],
#  ['Discrete Mathematics & Theoretical Computer Science'],
#  ['Hebdogiciel'],
#  ["Annales de Bretagne et des Pays de l'Ouest"],
#  ['Q2880986'],
#  ['Connaissance des arts'],
#  ['Annales. Histoire, Sciences sociales'],
#  ['Q3151427'],
#  ['La Recherche'],
#  ["Bulletin de l'École française d'Extrême-Orient"],
#  ['Le Fablier'],
#  ['Norois'],
#  ['Poétique'],
#  ["Revue d'Economie Politique"],
#  ['Revue Question(s) de Management'],
#  ['Annals of Economics and Statistics'],
#  ['Le Canard enchaîné'],
#  ['Pas-de-Calais Independent'],
#  ['Télérama'],
#  ['Le Journal du Dimanche'],
#  ['Politis'],
#  ['Télé Poche'],
#  ['Q729749'],
#  ['La Dépêche du Midi'],
#  ['Haratch'],
#  ["L'Express"],
#  ["L'Équipe"],
#  ['Le Monde diplomatique'],
#  ['Les Échos'],
#  ['Rue89'],
#  ['Charlie Hebdo'],
#  ["L'Obs"],
#  ['Q1097962'],
#  ['Jeune Afrique'],
#  ['La Quinzaine littéraire'],
#  ['Brazil'],
#  ['Causeur'],
#  ['Kornog'],
#  ['Q1674967'],
#  ['La Tribune'],
#  ['Stratégies'],
#  ['TV Magazine'],
#  ['Technikart'],
#  ['Q3538935'],
#  ['Télé 7 Jours'],
#  ['Valeurs Actuelles'],
#  ['Valeurs Actuelles'],
#  ['Q3563155'],
#  ['Q3570471'],
#  ['Q3592710'],
#  ['France Football'],
#  ['Positif'],
#  ['La Hulotte'],
#  ['Les Inrockuptibles'],
#  ['Q2823781'],
#  ['Q2825340'],
#  ['Agrimuse'],
#  ['Alternatives économiques'],
#  ['Art absolument'],
#  ['Art press'],
#  ['Q2933151'],
#  ['Q2939748'],
#  ['Q3002973'],
#  ['Q3047070'],
#  ['Genre & Histoire'],
#  ['Plaisir de France'],
#  ['Réforme'],
#  ['SO FOOT'],
#  ['Q55286723'],
#  ['Q2931935'],
#  ['Challenges'],
#  ['Q3010740'],
#  ['La Bougie du Sapeur'],
#  ['Q3134347'],
#  ['Q3186871'],
#  ['Q3201581'],
#  ["L'Argus"],
#  ['Q3204140'],
#  ['Q3205144'],
#  ["L'Œil électrique"],
#  ['Leaves'],
#  ['Politiques et management public'],
#  ['Nouvelle Revue Française'],
#  ['La Quinzaine littéraire'],
#  ['Q3205337'],
#  ['Record'],
#  ['Amis-Coop'],
#  ['Q16672681'],
#  ['La Revue Dessinée'],
#  ['Q21009281'],
#  ['Q21514710'],
#  ["Levant: cahiers de l'espace méditerranéen"],
#  ['Q3149145'],
#  ['Q3209216'],
#  ['La Nouvelle République du Centre-Ouest'],
#  ['Q3211914'],
#  ['Q3212643'],
#  ['La Tribune Républicaine'],
#  ['La Vie'],
#  ['Q3221870'],
#  ['Q3221895'],
#  ['Le Cri du peuple'],
#  ['Le Fablier'],
#  ['Le Gastronome'],
#  ['Huffington Post France'],
#  ['Q3224319'],
#  ["Le Monde de l'éducation"],
#  ['Q3224708'],
#  ['Le Pèlerin'],
#  ['Q3226113'],
#  ['Q3226277'],
#  ['Q3226743'],
#  ['Q3227888'],
#  ['Lignes'],
#  ['Poétique'],
#  ['Q3535682'],
#  ['Tout Prévoir'],
#  ['Q3570471'],
#  ['Q3578981'],
#  ['Q3579382'],
#  ['Q16667342'],
#  ['Q17356495'],
#  ['Q17356504'],
#  ['Q18823085'],
#  ['Q18836656'],
#  ['Q18836803'],
#  ['Q18837179'],
#  ['Q21013033'],
#  ['Lire'],
#  ['Q3480448'],
#  ["Levant: cahiers de l'espace méditerranéen"],
#  ['Photographie.com'],
#  ['Charlie Hebdo'],
#  ['Pif gadget'],
#  ['Q2907477'],
#  ['Grodada'],
#  ['Q3237841'],
#  ['Le Monde mensuel'],
#  ['Marianne (journal 1932-1940)'],
#  ['Terra Eco'],
#  ['Le Gorafi'],
#  ['Le Gorafi'],
#  ['Orient XXI'],
#  ['Néoplanète'],
#  ['Carmel'],
#  ['Q22047656'],
#  ['Q22054784'],
#  ['Q22248699'],
#  ['Les périphériques vous parlent'],
#  ['Q22927240'],
#  ['Savoirs'],
#  ['Q24025038'],
#  ['Q24150816'],
#  ['Bulletin officiel des Établissements français de l’Inde'],
#  ['Giff-Wiff'],
#  ['Q25389731'],
#  ['Q25932039'],
#  ['Q28495549'],
#  ['Le Télémaque'],
#  ['Revue du clergé français'],
#  ['Q38500285'],
#  ['Q40279698'],
#  ['Vers la tradition'],
#  ['Enfance (revue)'],
#  ['Q43459214'],
#  ['Poétique'],
#  ['Revue Jules Verne'],
#  ['La Loi'],
#  ['La République sociale indépendante'],
#  ["La Voix de l'Est"],
#  ['Le Cuir'],
#  ['Le Travailleur du Centre Ouest'],
#  ['Persée'],
#  ['Jazz Hot'],
#  ['Q2880986'],
#  ['Connaissance des arts'],
#  ['Annales. Histoire, Sciences sociales'],
#  ['Hebdogiciel'],
#  ['Q3151427'],
#  ['Cliopsy'],
#  ['Q26263213'],
#  ['Revue française des sciences de l’information et de la communication'],
#  ["Annales de Bretagne et des Pays de l'Ouest"],
#  ['La Recherche'],
#  ['Le Fablier'],
#  ['Norois'],
#  ['Sans fil'],
#  ['Q16303413'],
#  ['Q16536228'],
#  ['Q16682137'],
#  ['Discrete Mathematics & Theoretical Computer Science'],
#  ['La Russie opprimée'],
#  ['Paysan Breton'],
#  ['Q21514747'],
#  ["L'Hermine"],
#  ['Q28493296'],
#  ['Q28858842'],
#  ["Revue d'Economie Politique"],
#  ['Revue Question(s) de Management'],
#  ['Q22681427'],
#  ['Q24506902'],
#  ['Abeille du Bugey et du pays de Gex'],
#  ['Q26046063'],
#  ["L'Écho du Pas-de-Calais"],
#  ['La Démocratie pacifique'],
#  ["Le Courrier de l'Atlas"],
#  ['Le Petit Caporal'],
#  ['Zangou'],
#  ["L'Autorité"],
#  ["L'Éclair"],
#  ["L'Estafette"],
#  ["Bulletin de l'École française d'Extrême-Orient"],
#  ['Mon Lapin Quotidien'],
#  ['Le Garde National'],
#  ['Journal des Demoiselles'],
#  ['Q41939671'],
#  ["L'Antijuif algérien"],
#  ['La Comédie politique'],
#  ['Pro Armenia'],
#  ['Lyon Capitale'],
#  ['Q24067717'],
#  ['Q29340055'],
#  ['Psychologies'],
#  ['Q57330816'],
#  ['Q2817930'],
#  ['Q2823597'],
#  ['Q2844508'],
#  ['Le Film français'],
#  ['Le Particulier'],
#  ['Q3241710'],
#  ['Q3257267'],
#  ['L’Humanité Dimanche'],
#  ['Magic'],
#  ['Management'],
#  ['Q3295086'],
#  ['Objectif soins'],
#  ['Présence Africaine'],
#  ['Q3410409'],
#  ['Question de parents'],
#  ['Science & Vie'],
#  ['Septentrion'],
#  ['France Football'],
#  ['Positif'],
#  ['Jazz Hot'],
#  ['Jazz Magazine'],
#  ['Cahiers du cinéma'],
#  ['Le Palamède'],
#  ['Sport auto'],
#  ['Le Nouvel objectif Rhône-Alpes'],
#  ['Terra Eco'],
#  ['Transfuge'],
#  ['Trois couleurs magazine'],
#  ['Télé Loisirs'],
#  ['La Revue indépendante'],
#  ['Têtu'],
#  ['Pif gadget'],
#  ['Q2860164'],
#  ['Art actuel'],
#  ['Revue francaise des corps gras'],
#  ['Auto Plus'],
#  ['Auto Plus'],
#  ["L'Histoire"],
#  ['Beaux Arts magazine'],
#  ['Bremañ'],
#  ['Q2933141'],
#  ['Q3027999'],
#  ['Objectif Rhône-Alpes (2007)'],
#  ["Lyon mag'"],
#  ['Mag2 Lyon'],
#  ['Innov à Lyon'],
#  ['Football magazine'],
#  ['GNU/Linux Magazine France'],
#  ['Gala'],
#  ['Q3108990'],
#  ['Hebdogiciel'],
#  ['Q3151427'],
#  ['KR home-studio'],
#  ["L'Assiette au Beurre"],
#  ["L'Auto-Journal"],
#  ["L'Automobile Magazine"],
#  ['Q3205039'],
#  ["L'Écran français"],
#  ['Voici'],
#  ['Wik'],
#  ['Guide des lycées et collèges de la région lyonnaise'],
#  ['Q11933758'],
#  ['Reclams'],
#  ['Terra Nostra'],
#  ['Version.net'],
#  ["Bulletin de l'École française d'Extrême-Orient"],
#  ['Òc'],
#  ['Q14638330'],
#  ['Bonheurs magazine'],
#  ['Keyboards recording'],
#  ['Recording musicien'],
#  ['Keyboards home studio'],
#  ['Femina'],
#  ['The Good Life'],
#  ['Musique bretonne'],
#  ['Q16668777'],
#  ['Q16672681'],
#  ['Lyon quartiers'],
#  ['Ambiances lyonnaises'],
#  ['Q17621163'],
#  ['Clés pour le train miniature'],
#  ['Objectifs Rhône-Alpes'],
#  ['Place publique'],
#  ['Lyon découverte'],
#  ['PlayStation Magazine'],
#  ['Objectif Gard'],
#  ['Wind Magazine'],
#  ['Windsurfing'],
#  ['Q21639502'],
#  ['Sport free attitude'],
#  ['Annonces Automobile'],
#  ['Hypertextes et hypermédias'],
#  ['Critikat'],
#  ['Néo planète'],
#  ['Objectif soins & management'],
#  ['Annals of Economics and Statistics'],
#  ["Bulletin de la Société d'études scientifiques et archéologiques de la ville de Draguignan"],
#  ['Le Théâtre illustré'],
#  ["Les Cahiers de l'Entre-Deux-Mers (1994-2011)"],
#  ["Les Cahiers de l'Entre-Deux Mers"],
#  ['Q27962734'],
#  ['Q46237041'],
#  ['Q46620531'],
#  ['Koï'],
#  ['Annals of Economics and Statistics'],
#  ["Actes de la Société d'Histoire Naturelle de Paris"],
#  ["Le Panthéon de l'industrie"],
#  ['Conflits'],
#  ['Menorah'],
#  ['Revue française des sciences de l’information et de la communication'],
#  ['Journal de Mathematiques Pures et Appliquees'],
#  ['Acquisition and foreign language interaction'],
#  ['Bulletin de la Fédération jurassienne'],
#  ['Bulletin de Correspondance Hellenique'],
#  ['Q1097962'],
#  ['Politiques et management public'],
#  ['Q546262'],
#  ["L'Alsace-Le Pays"],
#  ["L'Indépendant"],
#  ['La Révolution surréaliste'],
#  ['Q3210503'],
#  ['La Marseillaise'],
#  ['La Nouvelle République du Centre-Ouest'],
#  ['Q3211916'],
#  ['La République des Pyrénées'],
#  ['Q3212596'],
#  ['Q3212752'],
#  ["La Tribune de l'art"],
#  ['Le Berry républicain'],
#  ['Le Bien Public'],
#  ['Le Chasseur français'],
#  ['Q3221872'],
#  ['Pif gadget'],
#  ['Sud-Ouest'],
#  ['Q2806611'],
#  ['Q2806646'],
#  ['Q2924549'],
#  ['Q2924583'],
#  ['Capital'],
#  ['Q2941272'],
#  ['Causette'],
#  ['Q2944867'],
#  ['Q2972325'],
#  ['Connaissance des arts'],
#  ['Q3001304'],
#  ['Q3222765'],
#  ['Q3223754'],
#  ['Le Journal du Centre'],
#  ['Le Maine Libre'],
#  ['Q3225336'],
#  ['Le Petit Bleu'],
#  ['Q3225416'],
#  ['Le Populaire du Centre'],
#  ['Q3226213'],
#  ['Q3458978'],
#  ['Science & Vie'],
#  ['Leaves'],
#  ['Q3053705'],
#  ['Q3064670'],
#  ['Q3117567'],
#  ['Q3119156'],
#  ['Q3123245'],
#  ['Hebdogiciel'],
#  ['Q3146577'],
#  ['Q3178011'],
#  ['Le Journal de la Côtière'],
#  ['Q3202297'],
#  ['Q3203718'],
#  ["L'Union"],
#  ['Q3204966'],
#  ['Q3205039'],
#  ["L'Écho républicain"],
#  ['Q3205559'],
#  ['Q3231238'],
#  ['Q3232601'],
#  ['Q3235258'],
#  ['Q3236286'],
#  ['Magic'],
#  ['Midi Olympique'],
#  ['Q3345184'],
#  ['La Quinzaine littéraire'],
#  ['Kornog'],
#  ['Brazil'],
#  ['Causeur'],
#  ['Q3360424'],
#  ['Patinage Magazine'],
#  ['Philosophie Magazine'],
#  ['Q3400446'],
#  ['Prima'],
#  ['Q3414503'],
#  ['Q3422072'],
#  ['Politiques et management public'],
#  ['Q3487233'],
#  ['Q3504637'],
#  ['Technikart'],
#  ['Land and People'],
#  ['Trax (magazine)'],
#  ['Tribune juive'],
#  ['Q3540241'],
#  ['Q3541634'],
#  ['Études'],
#  ['La Loi'],
#  ['Q18745517'],
#  ['Nord Littoral'],
#  ['Q18762364'],
#  ['Q18762368'],
#  ['Q18762370'],
#  ['Q19945265'],
#  ['Le Canard de Nantes à Brest'],
#  ["La Lettre de l'AFMA (Paris)"],
#  ['Le XIXe siècle'],
#  ['Q16467668'],
#  ['Q16534812'],
#  ['Q24931013'],
#  ['Q24932530'],
#  ['Zaporojetz'],
#  ["L'Est Républicain"],
#  ['Le Télégramme'],
#  ['Q3202605'],
#  ['Les Affiches de Paris (Paris. 1745)'],
#  ['Journal des théâtres, de littérature et des arts'],
#  ['Badminton Magazine - Revue de la Fédération Française de Badminton'],
#  ['France Badminton'],
#  ['Q16628316'],
#  ['Q16653731'],
#  ['Q16654015'],
#  ['Q16670221'],
#  ['Réseaux'],
#  ['La Montagne'],
#  ['La Réforme'],
#  ['Q3212596'],
#  ['Le Cri du peuple'],
#  ['Le Petit Quotidien'],
#  ['Le Républicain Lorrain'],
#  ['Q3365300'],
#  ['Q28495383'],
#  ['Q28495774'],
#  ['Le Progrès'],
#  ['Le Monde'],
#  ['Libération'],
#  ['Libération'],
#  ['Le Parisien'],
#  ['Nice-Matin'],
#  ['Le Figaro'],
#  ["Les Dernières Nouvelles d'Alsace"],
#  ["L'Opinion"],
#  ['Lyon Poche'],
#  ["L'Ecò dóu bousquetoun"],
#  ['Abeille du Bugey et du pays de Gex'],
#  ['Q42415327'],
#  ['Metropolitaine'],
#  ['France Info'],
#  ['Fier Panda'],
#  ['Q57461791'],
#  ['Q57466475'],
#  ['Corse-Matin'],
#  ["L'Humanité"],
#  ['La Croix'],
#  ['Midi Libre'],
#  ['20 minutes'],
#  ["Le Petit Bleu d'Agen"],
#  ['Q28790859'],
#  ['Paris'],
#  ["L'Équipe"],
#  ['Mediapart'],
#  ['La Provence'],
#  ['Nord Éclair'],
#  ['La Voix du Nord'],
#  ['Le Dauphiné Libéré'],
#  ['Atlantico'],
#  ['Famille chrétienne'],
#  ["Le Courrier d'Europe centrale"],
#  ['Lyon Poche'],
#  ["Voix de l'Ain"],
#  ['Q21197930'],
#  ['Le Petit Bleu de Lot-et-Garonne'],
#  ["Le Petit bleu de l'Agenais"]]
